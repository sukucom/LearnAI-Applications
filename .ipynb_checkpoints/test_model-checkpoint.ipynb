# %%
from transformers import pipeline

# Use a small model for testing
generator = pipeline("text-generation", model="gpt2")

result = generator("Nómaada in browser its coming correctly but in mobile gmail app Nomaada showing as normal o", max_length=30, truncation=True)
print(result[0]['generated_text'])
# Out:
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Once upon a time in AI, I went down to the bar to tell the bartender I was going to get a drink. He said, "You know, I've been to a bunch of bars and I've never heard a bartender ask you what you want to do this time of the week." I said, "Are you going to ask me what I would do if I were to be out here in the morning? Are you going to ask me what I would do if I were to be out here at night in the middle of the night?" And he said, "No, you don't have to go out to bars and tell me what I want to do. We can just do whatever we want." And I went out and got a drink. I'm not going to go out to bars because if I go out to bars and I'm out to get coffee, I'm going to go out to coffee because that's going to bring back my memories of being a bartender. And then I went to the bar and said, "I want to try this new drink. I want to try this new drink." And he said, "Yeah. I'm going to try it and then I'm going to try it again." And I went back to the bar and said, "OK. I
